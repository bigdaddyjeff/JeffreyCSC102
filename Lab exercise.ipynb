# %% [markdown]
# # Exercise
#
# # 20120612226
#
# # jeffrey.ibezim@pau.edu.ng

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#exercise 1
u = int(input("write a number"))
p = int(input("write a number"))

a = u - p
b = p - u

x = a * 2
y = b * 2

if u > p:
    if u > 17 :
        print(x)

if p > u:
    if p > 17:
        print(y)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#exercise 2
u = int(input("write a number"))
p = int(input("write a number"))
t = int(input("write a number"))

if u == p and p == t:
    print((u + p + t) * 3)
else:
    print( u + p + t)
# Out:
# write a number4
# write a number5
# write a number6
# 15

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# #exercise 3
# u = int(input("write a number""   "))
# p = int(input("write a number""   "))
#
# if u == p:
#     print("True")
# if u + p == 5:
#     print("True")
# if u - p == 5 or p - u == 5:
#     print("True")

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %%
#exercise 5
u = int(input("write a number""   "))



do = list(range(1,u))

d = 0

for i in do:
    e = i**3
    d = d + e
print(d)
# Out:
# write a number   5
# 100

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %%
#exercise 4
u = int(input("write a number"))
p = int(input("write a number"))
t = int(input("write a number"))

q = max(u,p,t)
v = min(u,p,t)

F = (u+p+t) - max(u,p,t) - min(u,p,t)

print(v,F,q)
